# %% [markdown]
# ## LAB 1 - PRACTICE PANDAS

# %% [markdown]
# #### PART -A

# %%
import pandas as pd
import numpy as np

students = pd.read_csv('student-mat.csv')   # Loading dataset into Pandas DataFrame
students
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
# without removing the index_col = 0, we have 31 columns

print(students.shape)
# Out:
# (395, 31)

# %%
# alternatively 

students = pd.read_csv('student-mat.csv', index_col = 0)  # column "school" is made an index 
students
# Out:
#        sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# school
# GP       F   18       U     GT3       A     4     4   at_home   teacher
# GP       F   17       U     GT3       T     1     1   at_home     other
# GP       F   15       U     LE3       T     1     1   at_home     other
# GP       F   15       U     GT3       T     4     2    health  services
# GP       F   16       U     GT3       T     3     3     other     other
# ...     ..  ...     ...     ...     ...   ...   ...       ...       ...
# MS       M   20       U     LE3       A     2     2  services  services
# MS       M   17       U     LE3       T     3     1  services  services
# MS       M   21       R     GT3       T     1     1     other     other
# MS       M   18       R     LE3       T     3     2  services     other
# MS       M   19       U     LE3       T     1     1     other   at_home
#
#         reason  ... internet  romantic  famrel  freetime goout Dalc Walc  \
# ...

# %%
print(students.shape)       # shape attribute of the dataframe returns a tuple 

# There are 395 rows (Q1) and 31 columns (Q2)
# Out:
# (395, 30)

# %%
students['age'].mean()    # Aggregation operation mean to find the average age

#The average age of the students is 16.6962 (Q3)
# Out:
# 16.696202531645568

# %%
students['freetime'].mean()     # Aggregation operation mean to find the average freetime

#The average freetime is 3.2354 (Q4)
# Out:
# 3.2354430379746835

# %%
students.groupby('grade').count()
# Out:
#        school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  \
# grade
# A          53   53   53       53       53       53    53    53    53    53
# B         103  103  103      103      103      103   103   103   103   103
# C         170  170  170      170      170      170   170   170   170   170
# F          69   69   69       69       69       69    69    69    69    69
#
#        ...  higher  internet  romantic  famrel  freetime  goout  Dalc  Walc  \
# grade  ...
# A      ...      53        53        53      53        53     53    53    53
# B      ...     103       103       103     103       103    103   103   103
# C      ...     170       170       170     170       170    170   170   170
# F      ...      69        69        69      69        69     69    69    69
#
#        health  absences
# grade
# A          53        53
# B         103       103
# C         170       170
# F          69        69
#
# [4 rows x 30 columns]

# %%
53/69   # Ratio of A to F

# The ratio of Grade A to Grade F is 0.7681 (Q5)
# Out:
# 0.7681159420289855

# %%
b = students.grade.value_counts()  # Alternate method for (Q5)
b
# Out:
# C    170
# B    103
# F     69
# A     53
# Name: grade, dtype: int64

# %%
b[3]/b[2]
# Out:
# 0.7681159420289855

# %%
students.groupby(['grade', 'sex']).count()     # (Q6)
# Out:
#            age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  reason  \
# grade sex
# A     F     23       23       23       23    23    23    23    23      23
#       M     30       30       30       30    30    30    30    30      30
# B     F     51       51       51       51    51    51    51    51      51
#       M     52       52       52       52    52    52    52    52      52
# C     F     94       94       94       94    94    94    94    94      94
#       M     76       76       76       76    76    76    76    76      76
# F     F     40       40       40       40    40    40    40    40      40
#       M     29       29       29       29    29    29    29    29      29
#
#            guardian  ...  higher  internet  romantic  famrel  freetime  goout  \
# grade sex            ...
# A     F          23  ...      23        23        23      23        23     23
#       M          30  ...      30        30        30      30        30     30
# ...

# %%
# The number of female students who received grade B or higher is 74  (Q6)

23 + 51
# Out:
# 74

# %%
# (Q7) store the students dataframe with replaced 'grade' column into 'new' dataframe

new = students.replace({'grade':{'A':4,'B':3,'C':2,'F':1,}})  # A dictionary where within 'grade' column A, B, C and F are 
                                                       # replaced with 4, 3, 2,1 respectively

# %%
new.info()  # The data type of grade column after replacement is int64
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 31 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
new.groupby('sex')['grade'].mean()    

# The average grade of female students according to the new grade scale is 2.2740  #(Q7)
# Out:
# sex
# F    2.274038
# M    2.443850
# Name: grade, dtype: float64

# %% [markdown]
# #### PART -B

# %%
food = pd.read_csv('Nutritional Data For Fast Foods.csv', index_col = 1)
food     # loading the food dataframe
# Out:
#                       Unnamed: 0                         Item          Type  \
# Fast Food Restaurant
# McDonald's                     0                    Hamburger        Burger
# McDonald's                     1                 Cheeseburger        Burger
# McDonald's                     2                            ?        Burger
# McDonald's                     3  Quarter Pounder with Cheese        Burger
# McDonald's                     4       Bacon Clubhouse Burger        Burger
# ...                          ...                          ...           ...
# In-N-Out Burger              121            Hamburger w/Onion        Burger
# In-N-Out Burger              122         Cheeseburger w/Onion        Burger
# In-N-Out Burger              123        Double-Double w/Onion        Burger
# In-N-Out Burger              124                 French Fries  French Fries
# In-N-Out Burger              125       Chocolate Shake (15oz)     Milkshake
#
# ...

# %%
food.drop('Unnamed: 0', axis = 1, inplace = True)
food
# Out:
#                                              Item          Type  \
# Fast Food Restaurant
# McDonald's                              Hamburger        Burger
# McDonald's                           Cheeseburger        Burger
# McDonald's                                      ?        Burger
# McDonald's            Quarter Pounder with Cheese        Burger
# McDonald's                 Bacon Clubhouse Burger        Burger
# ...                                           ...           ...
# In-N-Out Burger                 Hamburger w/Onion        Burger
# In-N-Out Burger              Cheeseburger w/Onion        Burger
# In-N-Out Burger             Double-Double w/Onion        Burger
# In-N-Out Burger                      French Fries  French Fries
# In-N-Out Burger            Chocolate Shake (15oz)     Milkshake
#
#                       Serving Size (g)  Calories  Total Fat (g)  \
# Fast Food Restaurant
# McDonald's                          98       240            8.0
# ...

# %%
food.info()

# The columns Item, Total Fat (g), Trans Fat (g), Sodium (mg), Protein (g) have missing values (Q8)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 126 entries, McDonald's to In-N-Out Burger
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Item               126 non-null    object
#  1   Type               126 non-null    object
#  2   Serving Size (g)   126 non-null    int64
#  3   Calories           126 non-null    int64
#  4   Total Fat (g)      122 non-null    float64
#  5   Saturated Fat (g)  126 non-null    float64
#  6   Trans Fat (g)      114 non-null    float64
#  7   Sodium (mg)        121 non-null    float64
#  8   Carbs (g)          126 non-null    float64
#  9   Sugars (g)         126 non-null    float64
#  10  Protein (g)        122 non-null    float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 11.8+ KB

# %%
foodn= food.replace({'?': np.nan})       # replace ? with np.nan
foodn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 126 entries, McDonald's to In-N-Out Burger
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Item               107 non-null    object
#  1   Type               126 non-null    object
#  2   Serving Size (g)   126 non-null    int64
#  3   Calories           126 non-null    int64
#  4   Total Fat (g)      122 non-null    float64
#  5   Saturated Fat (g)  126 non-null    float64
#  6   Trans Fat (g)      114 non-null    float64
#  7   Sodium (mg)        121 non-null    float64
#  8   Carbs (g)          126 non-null    float64
#  9   Sugars (g)         126 non-null    float64
#  10  Protein (g)        122 non-null    float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 11.8+ KB

# %%
b = food['Item'].nunique()
b

# There are 101 unique values in the column 'Item' (Q9)
# Out:
# 101

# %%
c = food['Type'].nunique()
c

# There are 6 unique values in the column 'Type' (Q10)
# Out:
# 6

# %%
d = food.groupby('Type').mean('Calories')
d

# The average calories for French Fries is 314.08 (Q11)
# Out:
#                           Serving Size (g)    Calories  Total Fat (g)  \
# Type
# Breaded Chicken Sandwich        215.727273  522.090909      26.018182
# Burger                          241.797101  620.202899      35.670769
# Chicken Nuggets                 100.545455  274.545455      17.372727
# French Fries                    109.500000  314.083333      15.308333
# Grilled Chicken Sandwich        216.090909  408.000000      17.000000
# Milkshake                       367.000000  606.666667      22.583333
#
#                           Saturated Fat (g)  Trans Fat (g)  Sodium (mg)  \
# Type
# Breaded Chicken Sandwich           4.563636       0.010000  1080.636364
# Burger                            13.563768       1.377419  1217.415385
# Chicken Nuggets                    3.054545       0.010000   697.636364
# French Fries                       2.891667       0.100000   375.833333
# Grilled Chicken Sandwich           3.863636       0.040000  1041.454545
# ...

# %%
food['Protein (g)'].idxmax()


#The fast-food restaurant Wendy's has the Burger with the highest protein per serving (Q12)
# Out:
# "Wendy's"
